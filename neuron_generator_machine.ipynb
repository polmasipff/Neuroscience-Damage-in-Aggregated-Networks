# %% [markdown]
# # The objective of this code is to generate neuronal networks

# %% [markdown]
# ### 1. Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ### 2. Setting up the network
